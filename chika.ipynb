# %%
import joblib
import pandas as pd


model_path = r'C:\Users\User\UNLABEL_MODEL\pipe.pkl'


# 2. Load the model
pipe = joblib.load(model_path)
print("Model loaded successfully!")

# 3. Prepare the new data
new_data = {
    'year': [1994],
    'sex': ['female'],
    'age_group': ['2'],
    'country': ['Zimbabwe'],
    'homicide_rate': [0.5],
    'rate_delta': [1.33],
    'moving_avg': [1.2222222],
    'prev_year_rate': [1234689.2]
}
new_df = pd.DataFrame(new_data)

# 4. Run the prediction
prediction = pipe.predict(new_df)

# 5. Output the result
print(f"The predicted result is: {prediction[0]}")
# Out:
# Model loaded successfully!
# The predicted result is: 1
